# %%
#!pip install keras==2.8.0
#!pip install tensorflow==2.8.0

# %%
import tensorflow as tf
import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.12.0
# Keras version: 2.12.0

# %%
#pip install tensorflow-gpu==2.8.0
# Out:
# Collecting tensorflow-gpu==2.8.0
#   Downloading tensorflow_gpu-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (23.5.26)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.56.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow-gpu==2.8.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.2.2)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.8.0

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.4
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.2.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      21.3.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.0
# arviz                            0.15.1
# astropy                          5.2.2
# astunparse                       1.6.3
# async-timeout                    4.0.2
# attrs                            23.1.0
# audioread                        3.0.0
# autograd                         1.6.2
# Babel                            2.12.1
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# bleach                           6.0.0
# blis                             0.7.9
# blosc2                           2.0.0
# bokeh                            2.4.3
# branca                           0.6.0
# build                            0.10.0
# CacheControl                     0.13.1
# cachetools                       5.3.1
# catalogue                        2.0.8
# certifi                          2023.5.7
# cffi                             1.15.1
# chardet                          4.0.0
# charset-normalizer               2.0.12
# chex                             0.1.7
# click                            8.1.4
# click-plugins                    1.1.1
# cligj                            0.7.2
# cloudpickle                      2.2.1
# cmake                            3.25.2
# cmdstanpy                        1.1.0
# colorcet                         3.0.1
# colorlover                       0.3.0
# community                        1.0.0b1
# confection                       0.1.0
# cons                             0.4.6
# contextlib2                      21.6.0
# contourpy                        1.1.0
# convertdate                      2.4.0
# cufflinks                        0.17.3
# cvxopt                           1.3.1
# cvxpy                            1.3.2
# cycler                           0.11.0
# cymem                            2.0.7
# Cython                           0.29.36
# dask                             2022.12.1
# datascience                      0.17.6
# db-dtypes                        1.1.1
# dbus-python                      1.2.16
# debugpy                          1.6.6
# decorator                        4.4.2
# defusedxml                       0.7.1
# distributed                      2022.12.1
# dlib                             19.24.2
# dm-tree                          0.1.8
# docutils                         0.16
# dopamine-rl                      4.0.6
# duckdb                           0.8.1
# earthengine-api                  0.1.358
# easydict                         1.10
# ecos                             2.0.12
# editdistance                     0.6.2
# en-core-web-sm                   3.5.0
# entrypoints                      0.4
# ephem                            4.1.4
# et-xmlfile                       1.1.0
# etils                            1.3.0
# etuples                          0.3.9
# exceptiongroup                   1.1.2
# fastai                           2.7.12
# fastcore                         1.5.29
# fastdownload                     0.0.7
# fastjsonschema                   2.17.1
# fastprogress                     1.0.3
# fastrlock                        0.8.1
# filelock                         3.12.2
# Fiona                            1.9.4.post1
# firebase-admin                   5.3.0
# Flask                            2.2.5
# flatbuffers                      23.5.26
# flax                             0.7.0
# folium                           0.14.0
# fonttools                        4.41.0
# frozendict                       2.3.8
# frozenlist                       1.4.0
# fsspec                           2023.6.0
# future                           0.18.3
# gast                             0.4.0
# gcsfs                            2023.6.0
# GDAL                             3.3.2
# gdown                            4.6.6
# gensim                           4.3.1
# geographiclib                    2.0
# geopandas                        0.13.2
# geopy                            2.3.0
# gin-config                       0.5.0
# glob2                            0.7
# google                           2.0.3
# google-api-core                  2.11.1
# google-api-python-client         2.84.0
# google-auth                      2.17.3
# google-auth-httplib2             0.1.0
# google-auth-oauthlib             0.4.6
# google-cloud-bigquery            3.10.0
# google-cloud-bigquery-connection 1.12.1
# google-cloud-bigquery-storage    2.22.0
# google-cloud-core                2.3.3
# google-cloud-datastore           2.15.2
# google-cloud-firestore           2.11.1
# google-cloud-functions           1.13.1
# google-cloud-language            2.9.1
# google-cloud-storage             2.8.0
# google-cloud-translate           3.11.2
# google-colab                     1.0.0
# google-crc32c                    1.5.0
# google-pasta                     0.2.0
# google-resumable-media           2.5.0
# googleapis-common-protos         1.59.1
# googledrivedownloader            0.4
# graphviz                         0.20.1
# greenlet                         2.0.2
# grpc-google-iam-v1               0.12.6
# grpcio                           1.56.0
# grpcio-status                    1.48.2
# gspread                          3.4.2
# gspread-dataframe                3.3.1
# gym                              0.25.2
# gym-notices                      0.0.8
# h5netcdf                         1.2.0
# h5py                             3.8.0
# holidays                         0.28
# holoviews                        1.15.4
# html5lib                         1.1
# httpimport                       1.3.0
# httplib2                         0.21.0
# humanize                         4.6.0
# hyperopt                         0.2.7
# idna                             3.4
# imageio                          2.25.1
# imageio-ffmpeg                   0.4.8
# imagesize                        1.4.1
# imbalanced-learn                 0.10.1
# imgaug                           0.4.0
# importlib-resources              6.0.0
# imutils                          0.5.4
# inflect                          6.0.5
# iniconfig                        2.0.0
# intel-openmp                     2023.1.0
# ipykernel                        5.5.6
# ipython                          7.34.0
# ipython-genutils                 0.2.0
# ipython-sql                      0.4.1
# ipywidgets                       7.7.1
# itsdangerous                     2.1.2
# jax                              0.4.13
# jaxlib                           0.4.13+cuda11.cudnn86
# jieba                            0.42.1
# Jinja2                           3.1.2
# joblib                           1.3.1
# jsonpickle                       3.0.1
# jsonschema                       4.3.3
# jupyter-client                   6.1.12
# jupyter-console                  6.1.0
# jupyter_core                     5.3.1
# jupyter-server                   1.24.0
# jupyterlab-pygments              0.2.2
# jupyterlab-widgets               3.0.8
# kaggle                           1.5.15
# keras                            2.8.0
# Keras-Preprocessing              1.1.2
# kiwisolver                       1.4.4
# langcodes                        3.3.0
# lazy_loader                      0.3
# libclang                         16.0.0
# librosa                          0.10.0.post2
# lightgbm                         3.3.5
# lit                              16.0.6
# llvmlite                         0.39.1
# locket                           1.0.0
# logical-unification              0.4.6
# LunarCalendar                    0.0.9
# lxml                             4.9.3
# Markdown                         3.4.3
# markdown-it-py                   3.0.0
# MarkupSafe                       2.1.3
# matplotlib                       3.7.1
# matplotlib-inline                0.1.6
# matplotlib-venn                  0.11.9
# mdurl                            0.1.2
# miniKanren                       1.0.3
# missingno                        0.5.2
# mistune                          0.8.4
# mizani                           0.8.1
# mkl                              2019.0
# ml-dtypes                        0.2.0
# mlxtend                          0.22.0
# more-itertools                   9.1.0
# moviepy                          1.0.3
# mpmath                           1.3.0
# msgpack                          1.0.5
# multidict                        6.0.4
# multipledispatch                 1.0.0
# multitasking                     0.0.11
# murmurhash                       1.0.9
# music21                          8.1.0
# natsort                          8.3.1
# nbclient                         0.8.0
# nbconvert                        6.5.4
# nbformat                         5.9.1
# nest-asyncio                     1.5.6
# networkx                         3.1
# nibabel                          3.0.2
# nltk                             3.8.1
# notebook                         6.4.8
# numba                            0.56.4
# numexpr                          2.8.4
# numpy                            1.22.4
# oauth2client                     4.1.3
# oauthlib                         3.2.2
# opencv-contrib-python            4.7.0.72
# opencv-python                    4.7.0.72
# opencv-python-headless           4.8.0.74
# openpyxl                         3.0.10
# opt-einsum                       3.3.0
# optax                            0.1.5
# orbax-checkpoint                 0.2.7
# osqp                             0.6.2.post8
# packaging                        23.1
# palettable                       3.3.3
# pandas                           1.5.3
# pandas-datareader                0.10.0
# pandas-gbq                       0.17.9
# pandocfilters                    1.5.0
# panel                            0.14.4
# param                            1.13.0
# parso                            0.8.3
# partd                            1.4.0
# pathlib                          1.0.1
# pathy                            0.10.2
# patsy                            0.5.3
# pexpect                          4.8.0
# pickleshare                      0.7.5
# Pillow                           8.4.0
# pip                              23.1.2
# pip-tools                        6.13.0
# platformdirs                     3.8.1
# plotly                           5.13.1
# plotnine                         0.10.1
# pluggy                           1.2.0
# polars                           0.17.3
# pooch                            1.6.0
# portpicker                       1.5.2
# prefetch-generator               1.0.3
# preshed                          3.0.8
# prettytable                      0.7.2
# proglog                          0.1.10
# progressbar2                     4.2.0
# prometheus-client                0.17.1
# promise                          2.3
# prompt-toolkit                   3.0.39
# prophet                          1.1.4
# proto-plus                       1.22.3
# protobuf                         3.20.3
# psutil                           5.9.5
# psycopg2                         2.9.6
# ptyprocess                       0.7.0
# py-cpuinfo                       9.0.0
# py4j                             0.10.9.7
# pyarrow                          9.0.0
# pyasn1                           0.5.0
# pyasn1-modules                   0.3.0
# pycocotools                      2.0.6
# pycparser                        2.21
# pyct                             0.5.0
# pydantic                         1.10.11
# pydata-google-auth               1.8.1
# pydot                            1.4.2
# pydot-ng                         2.0.0
# pydotplus                        2.0.2
# PyDrive                          1.3.1
# pyerfa                           2.0.0.3
# pygame                           2.5.0
# Pygments                         2.14.0
# PyGObject                        3.36.0
# pymc                             5.1.2
# PyMeeus                          0.5.12
# pymystem3                        0.2.0
# PyOpenGL                         3.1.7
# pyparsing                        3.1.0
# pyproj                           3.6.0
# pyproject_hooks                  1.0.0
# pyrsistent                       0.19.3
# PySocks                          1.7.1
# pytensor                         2.10.1
# pytest                           7.2.2
# python-apt                       0.0.0
# python-dateutil                  2.8.2
# python-louvain                   0.16
# python-slugify                   8.0.1
# python-utils                     3.7.0
# pytz                             2022.7.1
# pyviz-comms                      2.3.2
# PyWavelets                       1.4.1
# PyYAML                           6.0
# pyzmq                            23.2.1
# qdldl                            0.1.7.post0
# qudida                           0.0.4
# regex                            2022.10.31
# requests                         2.27.1
# requests-oauthlib                1.3.1
# requests-unixsocket              0.2.0
# requirements-parser              0.5.0
# rich                             13.4.2
# rpy2                             3.5.5
# rsa                              4.9
# scikit-image                     0.19.3
# scikit-learn                     1.2.2
# scipy                            1.10.1
# scs                              3.2.3
# seaborn                          0.12.2
# Send2Trash                       1.8.2
# setuptools                       67.7.2
# shapely                          2.0.1
# six                              1.16.0
# sklearn-pandas                   2.2.0
# smart-open                       6.3.0
# sniffio                          1.3.0
# snowballstemmer                  2.2.0
# sortedcontainers                 2.4.0
# soundfile                        0.12.1
# soupsieve                        2.4.1
# soxr                             0.3.5
# spacy                            3.5.4
# spacy-legacy                     3.0.12
# spacy-loggers                    1.0.4
# Sphinx                           3.5.4
# sphinxcontrib-applehelp          1.0.4
# sphinxcontrib-devhelp            1.0.2
# sphinxcontrib-htmlhelp           2.0.1
# sphinxcontrib-jsmath             1.0.1
# sphinxcontrib-qthelp             1.0.3
# sphinxcontrib-serializinghtml    1.1.5
# SQLAlchemy                       2.0.18
# sqlparse                         0.4.4
# srsly                            2.4.6
# statsmodels                      0.13.5
# sympy                            1.11.1
# tables                           3.8.0
# tabulate                         0.8.10
# tblib                            2.0.0
# tenacity                         8.2.2
# tensorboard                      2.8.0
# tensorboard-data-server          0.6.1
# tensorboard-plugin-wit           1.8.1
# tensorflow                       2.8.0
# tensorflow-datasets              4.9.2
# tensorflow-estimator             2.13.0
# tensorflow-gcs-config            2.12.0
# tensorflow-gpu                   2.8.0
# tensorflow-hub                   0.14.0
# tensorflow-io-gcs-filesystem     0.32.0
# tensorflow-metadata              1.13.1
# tensorflow-probability           0.20.1
# tensorstore                      0.1.40
# termcolor                        2.3.0
# terminado                        0.17.1
# text-unidecode                   1.3
# textblob                         0.17.1
# tf-estimator-nightly             2.8.0.dev2021122109
# tf-slim                          1.1.0
# thinc                            8.1.10
# threadpoolctl                    3.1.0
# tifffile                         2023.7.10
# tinycss2                         1.2.1
# toml                             0.10.2
# tomli                            2.0.1
# toolz                            0.12.0
# torch                            2.0.1+cu118
# torchaudio                       2.0.2+cu118
# torchdata                        0.6.1
# torchsummary                     1.5.1
# torchtext                        0.15.2
# torchvision                      0.15.2+cu118
# tornado                          6.3.1
# tqdm                             4.65.0
# traitlets                        5.7.1
# triton                           2.0.0
# tweepy                           4.13.0
# typer                            0.9.0
# types-setuptools                 68.0.0.1
# typing_extensions                4.5.0
# tzlocal                          5.0.1
# uritemplate                      4.1.1
# urllib3                          1.26.16
# vega-datasets                    0.9.0
# wasabi                           1.1.2
# wcwidth                          0.2.6
# webcolors                        1.13
# webencodings                     0.5.1
# websocket-client                 1.6.1
# Werkzeug                         2.3.6
# wheel                            0.40.0
# widgetsnbextension               3.6.4
# wordcloud                        1.8.2.2
# wrapt                            1.14.1
# xarray                           2022.12.0
# xarray-einstats                  0.6.0
# xgboost                          1.7.6
# xlrd                             2.0.1
# yarl                             1.9.2
# yellowbrick                      1.5
# yfinance                         0.2.22
# zict                             3.0.0
# zipp                             3.16.1

# %%
import tensorflow as tf
import os

# %%
os.path.join('data','no')
# Out:
# 'data/no'

# %%
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.list_physical_devices('GPU')
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import imghdr
from matplotlib import pyplot as plt
import PIL

# %%
data_dir = '/content/drive/MyDrive/data'

# %%
os.listdir(data_dir)
# Out:
# ['yes', 'no']

# %%
img_exts = ['jpeg','jpg','bmp','png','JPG']

# %%
img_no = cv2.imread(os.path.join(data_dir,'no','No18.jpg'))
img_yes = cv2.imread(os.path.join(data_dir,'yes','Y255.JPG'))

# %%
type(img_no)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_no,cv2.COLOR_BGR2RGB))
plt.title('NO tumor')
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_yes,cv2.COLOR_BGR2RGB))
plt.title('Tumor')
plt.show()

# %%
img_no.shape
# Out:
# (454, 442, 3)

# %%
for image_class in os.listdir(data_dir):
      for image in os.listdir(os.path.join(data_dir, image_class)):
        print(image)
# Out:
# Y161.JPG
# Y195.JPG
# Y17.jpg
# Y23.JPG
# Y14.jpg
# Y148.JPG
# Y154.jpg
# Y166.JPG
# Y24.jpg
# Y160.JPG
# Y16.JPG
# Y117.JPG
# Y21.jpg
# Y101.jpg
# Y10.jpg
# Y183.jpg
# Y18.JPG
# Y159.JPG
# Y112.JPG
# Y107.jpg
# Y156.JPG
# Y162.jpg
# Y169.jpg
# Y192.JPG
# Y2.jpg
# Y20.jpg
# Y193.JPG
# Y115.JPG
# Y155.JPG
# Y167.JPG
# Y188.jpg
# Y170.JPG
# Y158.JPG
# Y163.JPG
# Y120.JPG
# Y181.jpg
# Y153.jpg
# Y114.JPG
# Y184.JPG
# Y187.jpg
# Y194.jpg
# Y180.jpg
# Y106.jpg
# Y11.jpg
# Y13.jpg
# Y146.JPG
# Y100.JPG
# Y111.JPG
# Y103.jpg
# Y185.jpg
# Y186.jpg
# Y164.JPG
# Y113.JPG
# Y19.JPG
# Y147.JPG
# Y15.jpg
# Y168.jpg
# Y104.jpg
# Y182.JPG
# Y108.jpg
# Y109.JPG
# Y12.jpg
# Y116.JPG
# Y105.jpg
# Y165.JPG
# Y1.jpg
# Y157.JPG
# Y102.jpg
# Y22.jpg
# Y9.jpg
# Y255.JPG
# Y244.JPG
# Y60.jpg
# Y243.JPG
# Y62.jpg
# Y51.jpg
# Y245.jpg
# Y45.JPG
# Y73.jpg
# Y78.jpg
# Y252.jpg
# Y33.jpg
# Y92.jpg
# Y50.JPG
# Y256.JPG
# Y248.JPG
# Y99.JPG
# Y96.jpg
# Y55.jpg
# Y39.jpg
# Y44.JPG
# Y65.JPG
# Y47.JPG
# Y258.JPG
# Y247.JPG
# Y81.jpg
# Y70.jpg
# Y91.jpg
# Y37.jpg
# Y41.jpg
# Y69.jpg
# Y250.jpg
# Y251.JPG
# Y95.jpg
# Y29.jpg
# Y86.JPG
# Y40.JPG
# Y257.jpg
# Y56.jpg
# Y85.JPG
# Y90.jpg
# Y254.jpg
# Y35.jpg
# Y49.JPG
# Y249.JPG
# Y76.jpg
# Y34.jpg
# Y28.jpg
# Y58.JPG
# Y74.jpg
# Y98.JPG
# Y246.JPG
# Y30.jpg
# Y8.jpg
# Y59.JPG
# Y25.jpg
# Y4.jpg
# Y82.jpg
# Y36.JPG
# Y97.JPG
# Y79.jpg
# Y38.jpg
# Y6.jpg
# Y3.jpg
# Y7.jpg
# Y92.png
# Y253.JPG
# Y46.jpg
# Y259.JPG
# Y75.JPG
# Y242.JPG
# Y52.jpg
# Y26.jpg
# Y27.jpg
# Y32.jpg
# Y66.JPG
# Y89.JPG
# Y61.jpg
# Y71.JPG
# Y42.jpg
# Y54.jpg
# Y77.jpg
# Y31.jpg
# Y53.jpg
# Y67.JPG
# no 923.jpg
# no 91.jpeg
# 4 no.jpg
# no 99.jpg
# no 98.jpg
# 50 no.jpg
# no 95.jpg
# 44no.jpg
# no 5.jpeg
# 12 no.jpg
# no 94.jpg
# 22 no.jpg
# No19.jpg
# N6.jpg
# no 9.png
# N5.jpg
# 17 no.jpg
# 13 no.jpg
# N15.jpg
# no 6.jpg
# no 100.jpg
# 27 no.jpg
# no 97.jpg
# 11 no.jpg
# no 89.jpg
# 3 no.jpg
# N11.jpg
# 9 no.jpg
# 37 no.jpg
# 40 no.jpg
# 6 no.jpg
# 38 no.jpg
# no 92.jpg
# 5 no.jpg
# no 2.jpg
# No21.jpg
# No18.jpg
# No16.jpg
# 24 no.jpg
# No13.jpg
# N1.JPG
# no 8.jpg
# 25 no.jpg
# no 4.jpg
# no 1.jpg
# N17.jpg
# No14.jpg
# N26.JPG
# no.jpg
# 15 no.jpg
# 28 no.jpg
# No12.jpg
# N3.jpg
# 23 no.jpg
# 26 no.jpg
# 36 no.jpg
# 31 no.jpg
# 2 no.jpeg
# N19.JPG
# no 3.jpg
# N20.JPG
# no 10.jpg
# 10 no.jpg
# 45 no.jpg
# No15.jpg
# 43 no.jpg
# 33 no.jpg
# N22.JPG
# N2.JPG
# 14 no.jpg
# No20.jpg
# No17.jpg
# 42 no.jpg
# 30 no.jpg
# No22.jpg
# 32 no.jpg
# no 90.jpg
# 46 no.jpg
# No11.jpg
# 48 no.jpeg
# 34 no.jpg
# 49 no.jpg
# N21.jpg
# 1 no.jpeg
# 41 no.jpg
# 21 no.jpg
# 19 no.jpg
# 39 no.jpg
# no 96.jpg
# 7 no.jpg
# 35 no.jpg
# N16.jpg
# 18 no.jpg
# no 7.jpeg
# 8 no.jpg
# 29 no.jpg
# 47 no.jpg
# 20 no.jpg

# %%
print('Tumor images')
print(len(os.listdir('/content/drive/MyDrive/data/yes')))
print('No tumor images')
print(len(os.listdir('/content/drive/MyDrive/data/no')))
# Out:
# Tumor images
# 154
# No tumor images
# 96

# %%
image_path = os.path.join(data_dir, image_class, image)
image_path
# Out:
# '/content/drive/MyDrive/data/no/20 no.jpg'

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in img_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
# Out:
# Image not in ext list /content/drive/MyDrive/data/yes/Y46.jpg
# Image not in ext list /content/drive/MyDrive/data/no/no 4.jpg
# Image not in ext list /content/drive/MyDrive/data/no/N3.jpg

# %% [markdown]
# Data Augmentation

# %%
# img augmentation for no Tumor images
img_aug = cv2.imread(os.path.join(data_dir,'no','29 no.jpg'))
img_aug = cv2.cvtColor(img_aug, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_aug)

# %%
img_aug.shape
# Out:
# (234, 215, 3)

# %%
# doing data augmentation multiple times in different images

# %% [markdown]
# doing data augmentation multiple times in different images

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
img_aug = img_aug.reshape((1,) + img_aug.shape)  # this is a Numpy array with shape (1, *, *, *)

img_aug.shape
# Out:
# (1, 234, 215, 3)

# %%
i = 0
for batch in datagen.flow(img_aug, batch_size=1,
                          save_to_dir='/content/drive/MyDrive/data/no', save_prefix='no_tumor', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
print('Tumor images')
print(len(os.listdir('/content/drive/MyDrive/data/yes')))
print('No tumor images')
print(len(os.listdir('/content/drive/MyDrive/data/no')))
# Out:
# Tumor images
# 154
# No tumor images
# 117

# %%
import numpy as np

# %%
data = tf.keras.utils.image_dataset_from_directory(data_dir,batch_size=16)
# Out:
# Found 271 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
len(batch)
# Out:
# 2

# %%
len(batch[0])
# Out:
# 16

# %%
batch[0].shape
# Out:
# (16, 256, 256, 3)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# Scale Our Data

# %%
data = data.map(lambda x,y: (x/255, y))

# %%
batch = data.as_numpy_iterator().next()
batch[0].max()
# Out:
# 1.0

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %%
len(data)
# Out:
# 17

# %%
#Spliting the data

train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
val_size
# Out:
# 3

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
len(val)
# Out:
# 3

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
model = Sequential()
model.add(Conv2D(16, (3, 3), 1 ,input_shape=(256, 256, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), 1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (3, 3), 1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
tf.optimizers.Adam
# Out:
# keras.optimizers.adam.Adam

# %%
model.compile(optimizer='Adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      448
#
#  activation_3 (Activation)   (None, 254, 254, 16)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  activation_4 (Activation)   (None, 125, 125, 32)      0
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 16)        4624
#
#  activation_5 (Activation)   (None, 60, 60, 16)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 14400)             0
#
#  dense_2 (Dense)             (None, 64)                921664
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 931,441
# Trainable params: 931,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist= model.fit(train,epochs=20,validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 11/11 [==============================] - 5s 178ms/step - loss: 0.6239 - accuracy: 0.6818 - val_loss: 0.5499 - val_accuracy: 0.7500
# Epoch 2/20
# 11/11 [==============================] - 2s 113ms/step - loss: 0.5002 - accuracy: 0.7614 - val_loss: 0.4805 - val_accuracy: 0.7500
# Epoch 3/20
# 11/11 [==============================] - 2s 124ms/step - loss: 0.4455 - accuracy: 0.7784 - val_loss: 0.4998 - val_accuracy: 0.7917
# Epoch 4/20
# 11/11 [==============================] - 2s 168ms/step - loss: 0.3862 - accuracy: 0.8636 - val_loss: 0.3460 - val_accuracy: 0.8958
# Epoch 5/20
# 11/11 [==============================] - 1s 115ms/step - loss: 0.2905 - accuracy: 0.8807 - val_loss: 0.3600 - val_accuracy: 0.8750
# Epoch 6/20
# 11/11 [==============================] - 1s 107ms/step - loss: 0.2655 - accuracy: 0.9034 - val_loss: 0.2243 - val_accuracy: 0.8958
# Epoch 7/20
# 11/11 [==============================] - 1s 111ms/step - loss: 0.2053 - accuracy: 0.9375 - val_loss: 0.1741 - val_accuracy: 0.9167
# Epoch 8/20
# 11/11 [==============================] - 1s 107ms/step - loss: 0.1772 - accuracy: 0.9318 - val_loss: 0.1669 - val_accuracy: 0.9375
# Epoch 9/20
# 11/11 [==============================] - 1s 105ms/step - loss: 0.1098 - accuracy: 0.9716 - val_loss: 0.0742 - val_accuracy: 0.9583
# Epoch 10/20
# 11/11 [==============================] - 2s 171ms/step - loss: 0.0848 - accuracy: 0.9716 - val_loss: 0.0947 - val_accuracy: 0.9792
# Epoch 11/20
# 11/11 [==============================] - 2s 169ms/step - loss: 0.0680 - accuracy: 0.9830 - val_loss: 0.0784 - val_accuracy: 0.9792
# Epoch 12/20
# 11/11 [==============================] - 1s 108ms/step - loss: 0.0566 - accuracy: 0.9830 - val_loss: 0.0341 - val_accuracy: 0.9792
# Epoch 13/20
# 11/11 [==============================] - 1s 109ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 0.9792
# Epoch 14/20
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 15/20
# 11/11 [==============================] - 1s 108ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 16/20
# 11/11 [==============================] - 1s 105ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 17/20
# 11/11 [==============================] - 1s 109ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 18/20
# 11/11 [==============================] - 2s 196ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 19/20
# 11/11 [==============================] - 2s 127ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 20/20
# 11/11 [==============================] - 1s 112ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'],color='blue',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val loss')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'],color='Teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
from tensorflow.keras.metrics import Precision,Recall,BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc =BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
  X,y = batch
  yhat = model.predict(X)
  pre.update_state(y,yhat)
  re.update_state(y,yhat)
  acc.update_state(y,yhat)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
print("Precision",pre.result().numpy())
print("Recall",re.result().numpy())
print("Accuracy",acc.result().numpy())
# Out:
# Precision 1.0
# Recall 1.0
# Accuracy 1.0

# %% [markdown]
# Test On unseen data

# %%
img_test = cv2.imread('/content/drive/MyDrive/data/Test img.jpg')

# %%
img_test = cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB)
plt.imshow(img_test)

# %%
resize = tf.image.resize(img_test,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
resize.shape
# Out:
# TensorShape([256, 256, 3])

# %%
np.expand_dims(resize,0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255,0))
if yhat < 0.5:
  print(" There is no tumor in the brain ")

else:
  print("There is Tumor in the brain")

print(yhat)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# There is Tumor in the brain
# [[0.8772222]]

# %%
img_test2 = cv2.imread('/content/drive/MyDrive/data/Test_no.jpg')
img_test2 = cv2.cvtColor(img_test2, cv2.COLOR_BGR2RGB)
plt.imshow(img_test2)

# %%
resize1 = tf.image.resize(img_test2,(256,256))
plt.imshow(resize1.numpy().astype(int))
plt.show()

# %%
resize1.shape
# Out:
# TensorShape([256, 256, 3])

# %%
np.expand_dims(resize1,0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat2 = model.predict(np.expand_dims(resize1/255,0))

if yhat2 < 0.5:
  print(" There is no tumor in the brain ")
else:
  print("There is Tumor in the brain")
# Out:
# 1/1 [==============================] - 0s 19ms/step
#  There is no tumor in the brain
